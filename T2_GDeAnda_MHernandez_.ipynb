# %%
import sympy as sym
sym.init_printing(use_latex="mathjax")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Tarea 3.
#
# 1. Obtener máximos y mínimos absolutos, usando `sympy`, de las funciones dadas en los intervalos dados, y graficar la función en dicho intervalo señalando los puntos máximo y mínimo.
#
#     + $f(x)=2x^3+4x^2+1$ en $[-1.5,\,0.5]$
#     + $g(x) = 5x^3-3x+10$ en el intervalo $[-1, \,0]$

# %%
def f(x):
    return ((2 * x ** 3)+ (4 * x ** 2) + (1))
f(x)
# Out:
#    3      2
# 2⋅x  + 4⋅x  + 1

# %%
sym.var("x", real=True)
# Out:
# x

# %%
df = sym.diff(f(x),x)
df
# Out:
#    2
# 6⋅x  + 8⋅x

# %%
x_c = sym.solve(df,x)
x_c
# Out:
# [-4/3, 0]

# %%
f(-1.5),f(.5),f(-4/3),f(0)
# Out:
# (3.25, 2.25, 3.370370370370371, 1)

# %% [markdown]
# Solo nos interesan los puntos cuando x vale -4/3 que es punto máximo del intervalo y cuando x vale 0 que es el punto mínimo del intervalo $[-1.5,0.5]$

# %%
# Parte de la gráfica
xnum = np.linspace(-1.5,.5,150)
ynum = f(xnum)

# Tamaño de la gráfica
plt.figure(figsize=(12,8))

# Agregamos los gráficos
plt.plot(xnum,ynum,'--c',lw=6,label='$y=2x^3 + 4x^2 + 1$')
plt.plot([-4/3],[3.37037037037037],'Hb',ms=18,label='Punto máximo $(-4/3,3.37)$ en el intervalo')
plt.plot([0],[1],'or',ms=18,label='Punto mínimo $(0,1)$ en el intervalo ')

# Ejes de la gráfica
plt.xlabel('Eje de_las x',fontsize=18)
plt.ylabel('Eje de las y',fontsize=18)

plt.grid(color='black')
plt.legend(loc='best')
plt.show()
